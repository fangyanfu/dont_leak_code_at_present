# %%
import pandas as pd

df = pd.read_csv("./training_data.csv", encoding='cp1252')

df.head()
# Out:
#    OBS_ID KANAL  SHOW_ID           SHOW_DATUM FAKTOR  WORDING_ID  BRAND_FLG  \
# 0  235691   DIG   370117  30.07.2017 19:00:00      1       25802          1
# 1  235692   DIG   372896  04.08.2017 09:00:00      1       34013          0
# 2  235693   DIG   372896  04.08.2017 09:00:00      1       34013          0
# 3  235694   DIG   372896  04.08.2017 09:00:00      1       34013          0
# 4  235695   DIG   372896  04.08.2017 09:00:00      1       34013          0
#
#    BRAND_ID  WDHL_FLG  BESTELL_ID      ...                       WGH3_DESC  \
# 0      12.0         1      399879      ...       WGH-Stufe Marken National
# 1       NaN         0      399890      ...       WGH-Stufe Marken National
# 2       NaN         0      399890      ...       WGH-Stufe Marken National
# 3       NaN         0      399890      ...       WGH-Stufe Marken National
# 4       NaN         0      399890      ...       WGH-Stufe Marken National
#
# ...

# %%
X = df[["MENGE_FREI_SHOWBEGINN", "ONAIR_SEKUNDEN"]].values
Y = df[["SOLD_OUT_FLG"]].values

# %%
# KFold Cross Validation
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold

import numpy as np


kf = KFold(n_splits = 10, shuffle = True)
scores = cross_val_score(LinearRegression(), X, Y, cv = kf)

print(scores)
print(np.mean(scores))
# Out:
# [0.09597595 0.06953547 0.10093608 0.0837502  0.10972705 0.0928972
#  0.11555245 0.07989705 0.05292569 0.08653159]
# 0.08877287391274802

# %%
# Repeated KFold Cross Validation
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedKFold

import numpy as np


kf = KFold(n_splits = 10, shuffle = True)
scores = cross_val_score(LinearRegression(), X, Y, cv = RepeatedKFold(n_splits = 10, n_repeats = 10))

print(scores)
print(np.mean(scores))
# Out:
# [-5.36559832e-03 -1.66561537e-04 -5.62318276e-04 -4.62396711e-03
#  -1.23227959e-03 -6.36716372e-04 -5.30848417e-04 -3.45468866e-04
#  -2.15860702e-05  5.68142481e-05 -6.78273300e-03 -3.02299117e-04
#  -1.30222708e-03 -6.36146890e-04 -4.61590509e-04 -1.45183519e-03
#  -1.87703588e-03 -1.52382549e-03 -1.73467607e-03 -2.17525030e-03
#  -1.50523297e-03 -3.32271403e-03 -5.01941365e-05 -2.99382406e-03
#  -6.47908962e-03 -3.09835838e-03 -4.60088409e-04 -2.62474890e-03
#  -4.33910365e-04 -9.78223270e-04 -2.39945688e-03  5.77037681e-05
#   8.57994330e-05 -6.80335558e-04 -1.22681887e-03 -3.46998794e-03
#  -2.73184615e-04 -1.47326716e-03 -1.23466264e-03  1.40289249e-05
#  -1.69389425e-03 -2.86062223e-04 -4.19516370e-04 -1.84174838e-03
#  -1.20285740e-03 -7.59412371e-04 -8.87348831e-03 -1.30386115e-03
#  -7.79569556e-04 -1.30877338e-04 -8.75463924e-04  8.95183103e-07
#  -6.27088156e-03 -7.09580907e-03 -7.38511291e-03 -9.55969966e-04
# ...

# %%
# Bei erneutem Ausführen wird ein ziemlich ähnlicher Wert ausgegeben
